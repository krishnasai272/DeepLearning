# %% [markdown]
# <a href="https://colab.research.google.com/github/krishnasai272/DeepLearning/blob/main/C01_Error_Analysis(192325037).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

# Dataset
data = {
    'Time': [1, 2, 3, 4, 5, 6],
    'Battery Charge': [12, 24, 36, 48, 60, 71]
}
df = pd.DataFrame(data)

# Convert to classification
df['Label'] = df['Battery Charge'].apply(lambda x: 0 if x < 50 else 1)

# Train model
X = df[['Time']]
y = df['Label']

model = DecisionTreeClassifier()
model.fit(X, y)

#  input from user
time_input = float(input("Enter Time: "))

# Predict
predicted = model.predict([[time_input]])[0]

print("Predicted Label (0=Low, 1=High):", predicted)

# Ask user for actual value
actual = int(input("Enter Actual Label (0=Low, 1=High): "))

if predicted == actual:
    print("Result: ✅ Correct Prediction")
else:
    print("Result: ❌ Wrong Prediction")

# Accuracy for single input
accuracy = 1 if predicted == actual else 0
error = 1 - accuracy
print("Accuracy:", accuracy)
print("Error:", error)
# Out:
# Enter Time: 2
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# Predicted Label (0=Low, 1=High): 0
# Enter Actual Label (0=Low, 1=High): 1
# Result: ❌ Wrong Prediction
# Accuracy: 0
# Error: 1
