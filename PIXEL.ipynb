# %% [markdown]
# <a href="https://colab.research.google.com/github/krishnasai272/DeepLearning/blob/main/PIXEL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IMAGE TO PIXEL VALUE
from PIL import Image
import numpy as np
# Read image from user
image_path = input("C:\Users/Saiko/Pictures/Screenshots/Screenshot 2025-07-02 100906.png")

# Open image
img = Image.open(image_path)

# Convert image to NumPy array
pixels = np.array(img)

# Display image information
print("Image Shape:", pixels.shape)

print("\nPixel Values:")
print(pixels)

# %%
from PIL import Image
import numpy as np

# Load image
img = Image.open("leaf.jpg")

# Convert image to RGB
img = img.convert("RGB")

# Convert to NumPy array
pixels = np.array(img)

# Calculate average RGB values
avg_red = np.mean(pixels[:, :, 0])
avg_green = np.mean(pixels[:, :, 1])
avg_blue = np.mean(pixels[:, :, 2])

print("Average Red   :", round(avg_red, 2))
print("Average Green :", round(avg_green, 2))
print("Average Blue  :", round(avg_blue, 2))

# Identify dominant color
if avg_green > avg_red and avg_green > avg_blue:
    print("Leaf Color: GREEN")
elif avg_red > avg_green and avg_red > avg_blue:
    print("Leaf Color: BROWN/RED")
elif avg_blue > avg_red and avg_blue > avg_green:
    print("Leaf Color: BLUE")
else:
    print("Leaf Color: MIXED")
